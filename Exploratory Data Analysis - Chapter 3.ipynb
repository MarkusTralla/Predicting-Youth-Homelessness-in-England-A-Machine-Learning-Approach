# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', 500) #to not see elipses each time in displays of the dataframes
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
random_state = 88

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
# Common imports
import sys
assert sys.version_info >= (3, 5)
import sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import os
import seaborn as sns 

# For plotting
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
combined_data_eda = pd.read_excel("combined data final.xlsx") # PLEASE SPECIFY FILE PATH HERE

# %%
combined_data_eda.columns
# Out:
# Index(['Local Authority', 'Presentations', 'Children in Absolute Low Income', 'Housing Waitlist', 'Evictions', 'Number of Deaths from Drug Misuse', 'Welfare Claimant Count Age 16-24', 'Total Population', 'Population Aged 16-24', 'Total Recorded Crime', 'Total Domestic Abuse Incidents', 'Total Drug Offences', 'Median Earnings', 'IMD - Average rank ', 'IMD - Rank of average rank', 'IDACI - Average rank', 'IDACI - Rank of average rank ', 'Income Deprivation - Average rank ', 'Income Deprivation - Rank of average rank '], dtype='object')

# %%
combined_data_eda.drop(["IDACI - Average rank",'IDACI - Rank of average rank ','Income Deprivation - Average rank ',
                        'Income Deprivation - Rank of average rank '], axis=1, inplace=True)

# %%
combined_data_eda.hist(bins=50, figsize=(20,15))
plt.show()

# %%
combined_data_eda.drop(["IMD - Rank of average rank"], axis=1, inplace=True)

# %%
plt.figure(figsize=(14,12))
sns.heatmap(combined_data_eda.corr(),linewidths=.1,cmap="Blues", annot=True, annot_kws={"size": 11})
plt.yticks(rotation=0);
